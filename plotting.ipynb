# %% [markdown]
# ## Plotting

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %%
time = [0, 1, 2, 3]
position = [0, 100, 200, 300]

plt.plot(time, position)
plt.xlabel('Time (hr)')
plt.ylabel('Position (km)')
# Out:
# Text(0, 0.5, 'Position (km)')

# %%
#Plot data from dataframe
data = pd.read_csv('python-novice-gapminder-data/data/gapminder_gdp_oceania.csv', index_col='country')

# %%
# Extract year from last 4 characters of each column name
years = data.columns.str.strip('gdpPercap_')
# Convert year values to integers, saving results back to dataframe
data.columns = years.astype(int)

data.loc['Australia'].plot()

# %%
data.T.plot()
plt.ylabel('GDP per capita')
# Out:
# Text(0, 0.5, 'GDP per capita')

# %% [markdown]
# ## bar-chart

# %%
plt.style.use('ggplot')
data.T.plot(kind='bar')
plt.ylabel('GDP per capita')
# Out:
# Text(0, 0.5, 'GDP per capita')

# %%
gdp_australia = data.loc['Australia']

plt.plot(years, gdp_australia, 'g--')

# %%
# Select two countries' worth of data.
gdp_australia = data.loc['Australia']
gdp_nz = data.loc['New Zealand']

# Plot with differently-colored markers.
plt.plot(years, gdp_australia, 'b-', label='Australia')
plt.plot(years, gdp_nz, 'g-', label='New Zealand')

# Create legend.
plt.legend(loc='upper left')
plt.xlabel('Year')
plt.ylabel('GDP per capita ($)')
# Out:
# Text(0, 0.5, 'GDP per capita ($)')

# %%
plt.plot(years, gdp_australia, label='Australia')
plt.plot(years, gdp_nz, label='New Zealand')

# %%
plt.scatter(gdp_australia, gdp_nz)
data.T.plot.scatter('Australia', 'New Zealand')

# %%
# finding correlations

# %%
data_all = pd.read_csv('python-novice-gapminder-data/data/gapminder_all.csv', index_col='country')
data_all.plot(kind='scatter', x='gdpPercap_2007', y='lifeExp_2007',
              s=data_all['pop_2007']/1e6)

# %%
data_asia = pd.read_csv('python-novice-gapminder-data/data/gapminder_gdp_asia.csv', index_col='country')
data_asia.max().plot()
print(data_asia.idxmax())
print(data_asia.idxmin())
# Out:
# gdpPercap_1952          Kuwait
# gdpPercap_1957          Kuwait
# gdpPercap_1962          Kuwait
# gdpPercap_1967          Kuwait
# gdpPercap_1972          Kuwait
# gdpPercap_1977          Kuwait
# gdpPercap_1982    Saudi Arabia
# gdpPercap_1987          Kuwait
# gdpPercap_1992          Kuwait
# gdpPercap_1997          Kuwait
# gdpPercap_2002       Singapore
# gdpPercap_2007          Kuwait
# dtype: object
# gdpPercap_1952    Myanmar
# gdpPercap_1957    Myanmar
# gdpPercap_1962    Myanmar
# gdpPercap_1967    Myanmar
# gdpPercap_1972    Myanmar
# gdpPercap_1977    Myanmar
# gdpPercap_1982    Myanmar
# gdpPercap_1987    Myanmar
# gdpPercap_1992    Myanmar
# gdpPercap_1997    Myanmar
# gdpPercap_2002    Myanmar
# gdpPercap_2007    Myanmar
# dtype: object
